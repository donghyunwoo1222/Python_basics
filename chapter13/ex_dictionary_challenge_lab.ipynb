# %%
# LV1
book = {
    "title": "Python Basics",
    "price": 18000,
    "pages": 320,
    "in_stock": True
}

print(book["title"])

print(book["price"])

print(book["pages"])

print(book["in_stock"])
# Out:
# Python Basics
# 18000
# 320
# True

# %%
#LV2

student = {
    "name": "민수",
    "score": 80
}

student["city"] = "서울"
student["score"] = 95
removed = student.pop("city")
print(removed)
student["language"] = "Python"
del student["language"]
print(student)
# Out:
# 서울
# {'name': '민수', 'score': 95}

# %%
#LV3
product = {
    "name": "키보드",
    "price": 39000
}


print(product.get("stock"))

print(product.get("stock",0))

print("stock" in product)

print(product["stock"])
# Out:
# None
# 0
# False
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 14
#      10 print(product.get("stock",0))
#      11
#      12 print("stock" in product)
#      13
# ---> 14 print(product["stock"])
#
# KeyError: 'stock'

# %%
# LV 4

profile = {
    "name": "지영",
    "age": 24,
    "city": "부산",
    "language": "Python"
}

print(profile.keys())
print(profile.values())
print(profile.items())

for key, value in profile.items():
    print(f"{key}:{value}")
# Out:
# dict_keys(['name', 'age', 'city', 'language'])
# dict_values(['지영', 24, '부산', 'Python'])
# dict_items([('name', '지영'), ('age', 24), ('city', '부산'), ('language', 'Python')])
# name:지영
# age:24
# city:부산
# language:Python

# %%
# LV 5

scores = {
    "Python": 85,
    "SQL": 92,
    "AI": 78,
    "Data": 95
}

for score in scores.values():
    avg = sum(scores.values())/len(scores)
print(avg)
  
scores = {
    "Python": 85,
    "SQL": 92,
    "AI": 78,
    "Data": 95
}

for score in scores.values():
    if score >= 90:
        print(score)
# Out:
# 87.5
# 92
# 95

# %%
# LV 6


students = [
    {"name": "민수", "score": 85, "city": "서울"},
    {"name": "지영", "score": 92, "city": "부산"},
    {"name": "서준", "score": 78, "city": "서울"},
    {"name": "수진", "score": 96, "city": "대전"}
]
#첫 학생의 이름과 점수 조회
#여러 값을 가져오려면 각각 따로 키를 지정해서 가져와야 한다. 따라서 print() 안에서 쉼표로 연결해서 출력해야함
print(students[0]["name"], students[0]["score"])

for student in students:
    print(student["name"], student["score"])

for student in students:
    if student["score"] >= 80 and student["city"] == "서울":
        print(student)
# Out:
# 민수 85
# 민수 85
# 지영 92
# 서준 78
# 수진 96
# {'name': '민수', 'score': 85, 'city': '서울'}

# %%
# LV7

product = {
    "name": "노트북",
    "price": 1200000,
    "spec": {
        "ram": 16,
        "storage": 512,
        "display": {
            "size": 15.6,
            "resolution": "1920x1080"
        }
    }
}

spec = product["spec"]
display = spec["display"]
print(spec)
print(display)
print(display["resolution"])

# print(product["resolution"]) 이 오류가 나는 이유
# 파이썬은 대괄호 안에 적힌 키를 찾을때, 오직 그 딕셔너리의 가장 겉에서 먼저 찾는다.
# 즉, product안에 display가 있고 그 안에 resolution이 있는건데 product["resolution"]으로 입력하면 파이썬은 product에 resolution이 없다고 생각한다.
# Out:
# {'ram': 16, 'storage': 512, 'display': {'size': 15.6, 'resolution': '1920x1080'}}
# {'size': 15.6, 'resolution': '1920x1080'}
# 1920x1080

# %%
# LV9
# 방식 A 리스트

student_a = ["민수", 20, 85, "서울"]
student_a[2] = 95

print(student_a)

# 방식 B 딕셔너리

student_b = {
    "name": "민수",
    "age": 20,
    "score": 85,
    "city": "서울"
}
student_b["score"] = 95
student_b["language"] = "python"
print(student_b)
# Out:
# ['민수', 20, 95, '서울']
# {'name': '민수', 'age': 20, 'score': 95, 'city': '서울', 'language': 'python'}

# %%
user = {"name": "철수", "level": 1}

user["exp"] = 50
user["level"] = 2
print(user)
# Out:
# {'name': '철수', 'level': 2, 'exp': 50}

# %%
game_info = {"title": "파이썬 RPG", "version": 1.0}

print(game_info.get("publisher","제조사 모름"))

if "title" in game_info:
    print("true")
else:
    print("false")
# Out:
# 제조사 모름
# true

# %%
scores = {"국어": 90, "영어": 85, "수학": 95}

for key, value in scores.items():
    print(f"{key} : {value}")
# Out:
# 국어 : 90
# 영어 : 85
# 수학 : 95
